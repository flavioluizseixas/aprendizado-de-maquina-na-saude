# %% [markdown]
# <a href='https://colab.research.google.com/github/flavioluizseixas/aprendizado-de-maquina-na-saude/blob/main/1-Análise%20Exploratória%20e%20Regressão%20Logística/Explicação-Regressão-Logística.ipynb' target='_blank'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Abrir no Google Colab'/></a>

# %%
def generate_colab_link(username, repo, branch, notebook_path):
    # Substitui espaços por %20
    notebook_path_encoded = notebook_path.replace(" ", "%20")
    return f"https://colab.research.google.com/github/{username}/{repo}/blob/{branch}/{notebook_path_encoded}"

# Exemplo de uso
username = "flavioluizseixas"
repo = "aprendizado-de-maquina-na-saude"
branch = "main"
notebook_path = "1-Análise Exploratória e Regressão Logística/Explicação-Regressão-Logística.ipynb"

link = generate_colab_link(username, repo, branch, notebook_path)
print(f"<a href='{link}' target='_blank'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Abrir no Google Colab'/></a>")
# Out:
# <a href='https://colab.research.google.com/github/flavioluizseixas/aprendizado-de-maquina-na-saude/blob/main/1-Análise%20Exploratória%20e%20Regressão%20Logística/Explicação-Regressão-Logística.ipynb' target='_blank'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Abrir no Google Colab'/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Regressão logística
#
# ## O que é Regressão Logística?
#
# A regressão logística é uma técnica de modelagem estatística usada para prever a probabilidade de um resultado binário (com duas categorias) com base em uma ou mais variáveis independentes (também chamadas de preditoras). Ao contrário da regressão linear, que prevê um valor numérico contínuo, a regressão logística é usada para prever probabilidades que, em última análise, são classificadas em uma de duas categorias, como "sim/não", "sucesso/fracasso" ou "positivo/negativo".
#
# ## Como Funciona?
#
# A regressão logística transforma a combinação linear das variáveis preditoras em uma probabilidade, utilizando a função logística (ou sigmoide). A função logística mapeia qualquer valor real em um intervalo entre 0 e 1, o que é ideal para prever probabilidades.
#
# $$
# p(X) = \frac{1}{1 + e^{-(\beta_0 + \beta_1 X_1 + \dots + \beta_n X_n)}}
# $$
#
# - Explicação:
#   - $p(X)$ é a probabilidade prevista.
#   - $\beta_0$ é o intercepto.
#   - $\beta_1, \dots, \beta_n$ são os coeficientes para cada variável $X_1, \dots, X_n$.
#   - $e$ é a base do logaritmo natural (aproximadamente 2.718).
#
# # Interpretação dos Coeficientes
#
#   - $\beta_0$ (Intercepto): Representa o logaritmo das odds (razão de chances) do evento de interesse quando todas as variáveis preditoras são iguais a zero.
#
#   - $\beta_i$ (Coeficientes): Cada coeficiente - $\beta_i$
#   indica a mudança no logaritmo das odds associada a uma unidade de mudança na variável preditora $X_i$, mantendo todas as outras variáveis constantes. Um coeficiente positivo aumenta a probabilidade do evento, enquanto um coeficiente negativo a diminui.

# %%
def plot_logistic_function(x_min=-10, x_max=10, k=1, x0=0, num_points=500):
    """
    Plota a função logística no intervalo [x_min, x_max].
    
    Parâmetros:
    - x_min: limite inferior do intervalo x
    - x_max: limite superior do intervalo x
    - k: coeficiente que controla a inclinação
    - x0: ponto de inflexão (deslocamento horizontal)
    - num_points: número de pontos para plotar
    """
    # Gera os valores de x
    x = np.linspace(x_min, x_max, num_points)
    
    # Calcula a função logística
    y = 1 / (1 + np.exp(-k * (x - x0)))
    
    # Cria o gráfico
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f'k={k}, x0={x0}')
    plt.title('Gráfico da Função Logística')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.grid(True)
    plt.axvline(x=x0, color='gray', linestyle='--', label='x0')
    plt.axhline(y=0.5, color='red', linestyle='--', label='f(x)=0.5')
    plt.legend()
    plt.show()

# %%
# Exemplo de uso
plot_logistic_function(k=1, x0=0)
